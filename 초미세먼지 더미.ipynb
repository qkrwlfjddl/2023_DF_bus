# %%
import pandas as pd

# %%
data = pd.read_csv('C:/Users/82102/OneDrive/Documents/카카오톡 받은 파일/df.csv', encoding = 'cp949')

# %%
data
# Out:
#             day      Temp  rainfall       W_s       Humi        Dew  \
# 0    2022-01-01 -4.595652  0.200671  0.916291  44.391304 -15.078261
# 1    2022-01-02 -1.150000  0.139762  1.225000  58.875000  -8.450000
# 2    2022-01-03 -2.387500  0.000000  1.063273  56.083333 -10.100000
# 3    2022-01-04 -1.970833  0.000000  1.215160  55.000000 -10.566667
# 4    2022-01-05 -3.066667  0.200671  1.002468  46.375000 -13.104167
# ..          ...       ...       ...       ...        ...        ...
# 360  2022-12-27 -2.641667  0.200671  1.017643  69.208333  -7.687500
# 361  2022-12-28 -2.916667  0.048790  1.240787  58.916667 -10.191667
# 362  2022-12-29 -3.295833  0.000000  1.002468  54.375000 -11.454167
# 363  2022-12-30 -1.383333  0.000000  1.073294  65.708333  -7.362500
# 364  2022-12-31 -1.654167  0.000000  0.856187  65.708333  -7.241667
#
#            Press  rand_temp  See_1            W_d  이산화질소농도     오존농도  일산화탄소농도  \
# ...

# %%
def change_value(x):
    if x >= 35:
        return 1
    else:
        return 0

# 16열의 모든 행에 대해 apply 함수를 사용하여 값 변경
data.iloc[:, 15] = data.iloc[:, 15].apply(change_value)

data
# Out:
# C:\Users\82102\AppData\Local\Temp\ipykernel_18292\4052547481.py:8: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   data.iloc[:, 15] = data.iloc[:, 15].apply(change_value)
#             day      Temp  rainfall       W_s       Humi        Dew  \
# 0    2022-01-01 -4.595652  0.200671  0.916291  44.391304 -15.078261
# 1    2022-01-02 -1.150000  0.139762  1.225000  58.875000  -8.450000
# 2    2022-01-03 -2.387500  0.000000  1.063273  56.083333 -10.100000
# 3    2022-01-04 -1.970833  0.000000  1.215160  55.000000 -10.566667
# 4    2022-01-05 -3.066667  0.200671  1.002468  46.375000 -13.104167
# ..          ...       ...       ...       ...        ...        ...
# 360  2022-12-27 -2.641667  0.200671  1.017643  69.208333  -7.687500
# ...

# %%
data['초미세먼지농도'].value_counts()
# Out:
# 0    330
# 1     35
# Name: 초미세먼지농도, dtype: int64

# %%
file_path = 'C:/Users/82102/OneDrive/Documents/카카오톡 받은 파일/data.csv'
data.to_csv(file_path, index=False, encoding = 'cp949')
